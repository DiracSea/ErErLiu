# %%
import pandas as pd
import numpy as np

path1 = 'input/50D_kmeans'
path2 = 'input/tsne'
d50 = pd.read_table(path1,header=None,delim_whitespace=True)
d10 = pd.read_table(path2,header=None,delim_whitespace=True) 
print("input")
# Out:
# input

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
# %matplotlib inline

distortions = []
for i in range(1, 50):
    km = KMeans(
        n_clusters=i, init='random',
        n_init=10, max_iter=50,
        tol=1e-04, random_state=0
    )
    km.fit(d10)
    distortions.append(km.inertia_)

# plot
plt.plot(range(1, 50), distortions, marker='o')
plt.xlabel('Number of clusters')
plt.ylabel('Distortion')
plt.show()

# %%
distortions = []
for i in range(1, 30):
    km = KMeans(
        n_clusters=i, init='random',
        n_init=10, max_iter=30,
        tol=1e-04, random_state=0
    )
    km.fit(d50)
    distortions.append(km.inertia_)

# plot
plt.plot(range(1, 30), distortions, marker='o')
plt.xlabel('Number of clusters')
plt.ylabel('Distortion')
plt.show()

# %%
path1 = 'output/output/kmeans1/part-00000'
path2 = 'output/output/kmeans2/part-00000'
d50 = pd.read_table(path1,header=None,delim_whitespace=True)
d10 = pd.read_table(path2,header=None,delim_whitespace=True) 
print("input")
# Out:
# input

# %%
path1_1 = 'input/50D_kmeans'
path2_1 = 'input/tsne'
d50_1 = pd.read_table(path1_1,header=None,delim_whitespace=True)
d10_1 = pd.read_table(path2_1,header=None,delim_whitespace=True) 
print("input")
# Out:
# input

# %%
import random
number_of_colors = 40

color = ["#"+''.join([random.choice('0123456789ABCDEF') for j in range(6)])
             for i in range(number_of_colors)]
print(color)
# Out:
# ['#303668', '#A04934', '#453C82', '#37BF41', '#EDB7D2', '#BBB591', '#452E4F', '#6FB00C', '#89F746', '#E88F9E', '#9EB433', '#E19AB2', '#583F51', '#671441', '#08B026', '#6E3843', '#98914D', '#3ACEDA', '#4A6BBC', '#081450', '#852E0B', '#22740A', '#8A19A0', '#3EC3F0', '#A67C8B', '#F8E0C5', '#EE7C8D', '#9C007F', '#9DF856', '#A16B04', '#A2546B', '#89449E', '#C9F504', '#F39778', '#FE9F8A', '#BBF6B1', '#582175', '#DED1C4', '#74B326', '#4EDEB7']

# %%
a = pd.concat([d10_1, d10], axis=1) 
b = pd.concat([d50_1, d50], axis=1)
a.columns = ['x', 'y', 'l']
b.columns = ['x', 'y', 'l']
print(a)
print(b)
# Out:
#              x          y  l
# 0    -0.690833  21.335594  1
# 1    -7.180656  28.318122  1
# 2    17.504005 -29.843293  0
# 3   -14.350988  14.798520  3
# 4   -16.923601   2.450484  3
# ..         ...        ... ..
# 333  -0.720807 -19.067411  2
# 334  -2.167474  20.200506  1
# 335  -2.663640 -13.669799  2
# 336  -4.103606   3.009145  2
# 337 -12.986966  18.269782  3
#
# [338 rows x 3 columns]
#                x          y  l
# 0      -2.222969  33.032824  0
# 1      29.837827  18.272434  5
# 2      -4.151006  25.802500  0
# 3     -22.031649  -0.356361  3
# 4     -27.845344  -4.044633  3
# ...          ...        ... ..
# 35502 -24.611937   7.282272  3
# 35503   9.077362 -26.209376  2
# 35504  -2.711273  14.821666  0
# 35505  31.340127  11.498357  5
# 35506   2.806757  11.655756  0
#
# [35507 rows x 3 columns]

# %%
a0 = a[a['l'] == 0]
a1 = a[a['l'] == 1]
a2 = a[a['l'] == 2]
a3 = a[a['l'] == 3]
print(a0)

b0 = b[b['l'] == 0]
b1 = b[b['l'] == 1]
b2 = b[b['l'] == 2]
b3 = b[b['l'] == 3]
b4 = b[b['l'] == 4]
b5 = b[b['l'] == 5]
# Out:
#              x          y  l
# 2    17.504005 -29.843293  0
# 8     9.711047 -11.087583  0
# 11   20.419397 -26.836207  0
# 16   16.376855 -25.686275  0
# 18   12.245703 -23.607413  0
# ..         ...        ... ..
# 299  18.358963 -17.611927  0
# 303  12.311968 -10.288703  0
# 311   4.498711 -16.611535  0
# 312   8.545829 -11.165779  0
# 317  10.236443 -23.944546  0
#
# [106 rows x 3 columns]

# %%
from sklearn.cluster import KMeans
from sklearn import metrics

plt.figure
# correct number of clusters
# estimator= KMeans(n_clusters=3, random_state=random_state)
# y_pred =estimator.fit_predict(X)

plt.scatter(a0['x'],a0['y'],c='r',marker='.')
plt.scatter(a1['x'],a1['y'],c='b',marker='.')
plt.scatter(a2['x'],a2['y'],c='g',marker='.')
plt.scatter(a3['x'],a3['y'], c = 'yellow',marker='.')
plt.show()

# %%
plt.figure

plt.scatter(b0['x'],b0['y'],c=color[0],marker='.')
plt.scatter(b1['x'],b1['y'],c=color[1],marker='.')
plt.scatter(b2['x'],b2['y'],c=color[2],marker='.')
plt.scatter(b3['x'],b3['y'], c =color[7],marker='.')
plt.scatter(b4['x'],b4['y'],c=color[5],marker='.')
plt.scatter(b5['x'],b5['y'], c = color[6],marker='.')
plt.show()

# %%
from pyecharts import options as opts
from pyecharts.charts import Scatter


def scatter_base() -> Scatter:
    c = (
        Scatter()
        .add_xaxis(Faker.choose())
        .add_yaxis("商家A", Faker.values())
        .set_global_opts(title_opts=opts.TitleOpts(title="Scatter-基本示例"))
    )
    return c
scatter_basa().render_notebook()
